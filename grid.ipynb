# %% [markdown]
# Q1.Create an image gallery using a CSS grid.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="q1.css">
  <title>Document</title>
</head>
<body>
  <div class="container">
    <div class="img1">
    <img src="https://cdn.pixabay.com/photo/2024/05/14/23/40/aigenerated-8762318_1280.png">
    </div>
    <div class="img2">
    <img src="https://cdn.pixabay.com/photo/2023/01/19/19/49/aigenerated-7730101_1280.jpg">
    </div>
    <div class="img3">
    <img src="https://cdn.pixabay.com/photo/2023/09/25/03/27/aigenerated-8274116_1280.png">
    </div>
    <div class="img4">
    <img src="https://cdn.pixabay.com/photo/2023/12/22/20/57/aigenerated-8464364_1280.jpg">
    </div>
    <div class="img5">
    <img src="https://cdn.pixabay.com/photo/2024/03/16/20/35/aigenerated-8637800_1280.jpg">
    </div>
    <div class="img6">
    <img src="https://cdn.pixabay.com/photo/2024/04/22/17/03/aigenerated-8713076_1280.png">
    </div>
  </div>
</body>
</html>

# %%
.container {
display: grid;
grid-template-columns: repeat(3, 1fr);
grid-template-rows: repeat(3, 200px);
gap: 8px;
}
img {
display: grid;
width: 100%;
height: 100%;
object-fit: cover;
}
.img1 {
grid-row: 1 / 2;
grid-column: 1 / 3;
}
.img2 {
grid-row: 1 /2;
grid-column: 3 / 4;
}
.img3 {
grid-row: 2 / 4;
grid-column: 1 / 2;
}
,.img4 {
grid-row: 2 / 3;
grid-column: 2 / 3;
}
.img5 {
grid-row: 3 /4;
grid-column: 2 / 3;
}
.img6 {
grid-row: 2 / 4;
grid-column: 3 / 4;
}

# %% [markdown]
# Q2.Write code to arrange containers with texts A, B, C, and D as shown in the below image.

# %% [markdown]
# ![Screenshot 2025-06-02 at 11.15.54 PM.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<link rel="stylesheet" href="q2.css">
<title>Document</title>
</head>
<body>
<div class="container">
<div class="boxa box">A</div>
<div class="boxb box">B</div>
<div class="boxc box">C</div>
<div class="boxd box">D</div>
</div>
</body>
</html>

# %%
* {
margin: 50px 50px 50px 50px;
}
.container {
display: grid;
grid-template-columns: repeat(3, 1fr);
border-radius: 10px;
box-sizing: border-box;
gap: 0.5rem ;
}
.box {
border-radius: 6px;
height: 100%;
width: 100%;
background-color: bisque;
}
.boxa {
grid-column: 1 / 3 ;
grid-row: 1 / 2;
}
.boxb {
grid-row: 1 / 4;
grid-column: 3 /4;
}
.boxc {
grid-row: 2 / 4;
grid-column: 1 /2;
}
.boxd {
grid-row: 2 / 4;
grid-column: 2 / 3;
}

# %% [markdown]
# Q3.Explain the use of grid-auto-row and grid-auto-column using code examples.

# %% [markdown]
# The grid-auto-rows and grid-auto-columns properties in CSS Grid are used to define the size of implicitly created rows or columns—i.e., those that are not explicitly defined in the grid-template-rows or grid-template-columns.
#
# 1.grid-auto-rows
# Purpose: Specifies the height of automatically created rows.
#
# Used when: Grid items are placed in rows that aren't explicitly defined.

# %%
<style>
  .grid-container {
    display: grid;
    grid-template-columns: 100px 100px;
    grid-auto-rows: 80px;
    gap: 10px;
    background: #f3f3f3;
  }

  .grid-item {
    background: lightblue;
    padding: 10px;
    text-align: center;
  }
</style>

<div class="grid-container">
  <div class="grid-item">1</div>
  <div class="grid-item">2</div>
  <div class="grid-item">3</div> <!-- Implicit row -->
  <div class="grid-item">4</div>
</div>

# %% [markdown]
# 2.grid-auto-columns
# Purpose: Specifies the width of automatically created columns.
#
# Used when: Grid items are placed in columns that aren't explicitly defined.

# %%
<style>
  .grid-container {
    display: grid;
    grid-template-rows: 100px;
    grid-auto-columns: 120px;
    grid-auto-flow: column;
    gap: 10px;
    background: #fafafa;
  }

  .grid-item {
    background: lightgreen;
    padding: 10px;
    text-align: center;
  }
</style>

<div class="grid-container">
  <div class="grid-item">A</div>
  <div class="grid-item">B</div>
  <div class="grid-item">C</div> <!-- Implicit column -->
</div>

# %% [markdown]
# Q4: Problem Statement Write CSS to show numbers as shown in the figure, without
# altering the below html code.

# %%
<!-- <div class="container">
<div class="box box1">1</div>
<div class="box box2">2</div>
<div class="box box3">3</div>
<div class="box box4">4</div>
<div class="box box5">5</div>
<div class="box box6">6</div>
<div class="box box7">7</div>
<div class="box box8">8</div>
</div> -->

# %% [markdown]
# ![Screenshot 2025-06-02 at 11.23.44 PM.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<link rel="stylesheet" href="q4.css">
<title>Document</title>
</head>
<body>
<div class="container">
<div class="box box1">1</div>
<div class="box box2">2</div>
<div class="box box3">3</div>
<div class="box box4">4</div>
<div class="box box5">5</div>
<div class="box box6">6</div>
<div class="box box7">7</div>
<div class="box box8">8</div>
</div>
</body>
</html>

# %%
* {
margin: 50px 50px 50px 50px ;
}
.container {
display: grid;
grid-template-columns: repeat(6, 1fr);
grid-template-rows: repeat(2, 50px);
box-sizing: border-box;
gap: 0.4rem;
}
.box {
display: flex;
width: 100%;
height: 100%;
border-radius: 4px;
align-items: center;
justify-content: center;
font-size: 24px;
font-weight: bold;
}
.box1 {
grid-row: 2 / 3;
grid-column: 1 / 2;
}
.box2 {
grid-column: 2/3;
grid-row: 2/3;
}
.box3 {
grid-row: 1 / 2;
grid-column: 1 / 2;
}
.box4 {
grid-row: 1 / 2;
grid-column: 2 /3 ;
}
.box5 {
grid-row: 1 / 2;
grid-column: 3 / 4;
}
.box6 {
grid-row: 1 / 2;
grid-column: 4 /5 ;
}
.box7 {
grid-row: 1 / 2;
grid-column: 5 / 6;
}
.box8 {
grid-row: 1 / 2;
grid-column: 6 /7 ;
}
.box1, .box3, .box5, .box7 {
background-color: #3a3737;
color: white;
}
.box2, .box4, .box6, .box8 {
background-color:  rgb(212, 210, 210);
color: black;
}

# %% [markdown]
# Q5.Explain the difference between justify-items and justify-self using code examples.

# %% [markdown]
# Both justify-items and justify-self play important roles in controlling the horizontal alignment of elements within CSS Grid layouts, but they operate at different levels. The justify-items property is set on the grid container and establishes the default horizontal alignment for all child grid items. It accepts values such as start, center, end, and stretch, which determine how each item is positioned within its grid cell along the inline (horizontal) axis. For example, justify-items: center centers every grid item horizontally in their respective cells, providing a uniform alignment across the entire grid.
#
# In contrast, justify-self targets individual grid items and overrides the container’s justify-items value for that specific item only. This makes it useful when you want most items to follow a general alignment rule but need one or a few items to behave differently. For example, if the container’s justify-items is set to start, all items will align to the left, but an item with justify-self: end will align to the right inside its grid cell. This granular control allows developers to create flexible and responsive layouts without having to restructure the entire grid.
#
# Both properties enhance the versatility of CSS Grid by separating concerns between global container-level alignment (justify-items) and local item-level overrides (justify-self). They complement each other to help designers and developers create visually balanced and precise layouts. Additionally, these properties have vertical counterparts, align-items and align-self, which work along the block (vertical) axis in a similar way. Understanding and using justify-items and justify-self effectively allows for fine control over the positioning of elements, improving both aesthetics and usability in modern web design.

# %%
..container {
display: grid;
grid-template-columns: repeat(3, 100px);
grid-template-rows: repeat(2, 100px);
gap: 0.4rem;
justify-items: center;
}
.box {
background-color: aqua;
}

# %%
.container {
display: grid;
grid-template-columns: repeat(3, 100px);
grid-template-rows: repeat(2, 100px);
gap: 0.4rem;
}
.box {
background-color: aqua;
}
.box1 {
align-self:center ;
}
